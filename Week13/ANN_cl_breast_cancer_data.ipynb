# %% [markdown]
# ### Artificial Neural Network

# %% [markdown]
# ##### 2020710058 Applied Data Science Doo-yeonog, Lee

# %%
# Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Importing data
data = pd.read_csv('data.csv')
del data['Unnamed: 32']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
#  14  perimeter_se             569 non-null    float64
#  15  area_se                  569 non-null    float64
#  16  smoothness_se            569 non-null    float64
#  17  compactness_se           569 non-null    float64
#  18  concavity_se             569 non-null    float64
#  19  concave points_se        569 non-null    float64
#  20  symmetry_se              569 non-null    float64
#  21  fractal_dimension_se     569 non-null    float64
#  22  radius_worst             569 non-null    float64
#  23  texture_worst            569 non-null    float64
#  24  perimeter_worst          569 non-null    float64
#  25  area_worst               569 non-null    float64
#  26  smoothness_worst         569 non-null    float64
#  27  compactness_worst        569 non-null    float64
#  28  concavity_worst          569 non-null    float64
#  29  concave points_worst     569 non-null    float64
#  30  symmetry_worst           569 non-null    float64
#  31  fractal_dimension_worst  569 non-null    float64
# dtypes: float64(30), int64(1), object(1)
# memory usage: 142.4+ KB

# %%
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0  ...         25.38          17.33           184.60      2019.0
# 1  ...         24.99          23.41           158.80      1956.0
# 2  ...         23.57          25.53           152.50      1709.0
# 3  ...         14.91          26.50            98.87       567.7
# 4  ...         22.54          16.67           152.20      1575.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal_dimension_worst
# 0          0.4601                  0.11890
# 1          0.2750                  0.08902
# 2          0.3613                  0.08758
# 3          0.6638                  0.17300
# 4          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %%
X = data.iloc[:, 2:].values
y = data.iloc[:, 1].values

# Encoding categorical data
from sklearn.preprocessing import LabelEncoder
labelencoder_X_1 = LabelEncoder()
y = labelencoder_X_1.fit_transform(y)

# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = 0)

#Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\tensorflow\python\pywrap_tensorflow.py in <module>
#      63   try:
# ---> 64     from tensorflow.python._pywrap_tensorflow_internal import *
#      65   # This try catch logic is because there is no bazel equivalent for py_extension.
#
# ImportError: DLL load failed while importing _pywrap_tensorflow_internal: DLL 초기화 루틴을 실행할 수 없습니다.
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\keras\__init__.py in <module>
#       2 try:
# ----> 3     from tensorflow.keras.layers.experimental.preprocessing import RandomRotation
#       4 except ImportError:
#
# ~\anaconda3\lib\site-packages\tensorflow\__init__.py in <module>
#      40
# ---> 41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#
# ~\anaconda3\lib\site-packages\tensorflow\python\__init__.py in <module>
#      38 # pylint: disable=wildcard-import,g-bad-import-order,g-import-not-at-top
# ---> 39 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow
#      40
#
# ~\anaconda3\lib\site-packages\tensorflow\python\pywrap_tensorflow.py in <module>
#      82 above this error message when asking for help.""" % traceback.format_exc()
# ---> 83   raise ImportError(msg)
#      84
#
# ImportError: Traceback (most recent call last):
#   File "C:\Users\Lee\anaconda3\lib\site-packages\tensorflow\python\pywrap_tensorflow.py", line 64, in <module>
#     from tensorflow.python._pywrap_tensorflow_internal import *
# ImportError: DLL load failed while importing _pywrap_tensorflow_internal: DLL 초기화 루틴을 실행할 수 없습니다.
#
#
# Failed to load the native TensorFlow runtime.
#
# See https://www.tensorflow.org/install/errors
#
# for some common reasons and solutions.  Include the entire stack trace
# above this error message when asking for help.
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-6-adb16916f554> in <module>
# ----> 1 import keras
#       2 from keras.models import Sequential
#       3 from keras.layers import Dense, Dropout
#
# ~\anaconda3\lib\site-packages\keras\__init__.py in <module>
#       3     from tensorflow.keras.layers.experimental.preprocessing import RandomRotation
#       4 except ImportError:
# ----> 5     raise ImportError(
#       6         'Keras requires TensorFlow 2.2 or higher. '
#       7         'Install TensorFlow via `pip install tensorflow`')
#
# ImportError: Keras requires TensorFlow 2.2 or higher. Install TensorFlow via `pip install tensorflow`

# %%
# Initialising the ANN
classifier = Sequential()

# %%
# Adding the input layer and the first hidden layer
classifier.add(Dense(16, activation='relu', input_dim=30))
# Adding dropout to prevent overfitting
classifier.add(Dropout(0.1))

# %%
# Adding the second hidden layer
classifier.add(Dense(16, activation='relu'))
# Adding dropout to prevent overfitting
classifier.add(Dropout(0.1))

# %%
# Adding the output layer
classifier.add(Dense(1, activation='sigmoid'))

# %%
# Compiling the ANN
classifier.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Fitting the ANN to the Training set
classifier.fit(X_train, y_train, batch_size=100, epochs=150)
# Out:
# Epoch 1/150
# 6/6 [==============================] - 0s 1ms/step - loss: 0.7009 - accuracy: 0.6621
# Epoch 2/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.5905 - accuracy: 0.7207
# Epoch 3/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.5036 - accuracy: 0.7949
# Epoch 4/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.4474 - accuracy: 0.8496
# Epoch 5/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.4043 - accuracy: 0.8789
# Epoch 6/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.3611 - accuracy: 0.8887
# Epoch 7/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.3172 - accuracy: 0.9121
# Epoch 8/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2825 - accuracy: 0.9199
# Epoch 9/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2484 - accuracy: 0.9395
# Epoch 10/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2324 - accuracy: 0.9297
# Epoch 11/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2124 - accuracy: 0.9336
# Epoch 12/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2084 - accuracy: 0.9395
# Epoch 13/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1893 - accuracy: 0.9453
# Epoch 14/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1679 - accuracy: 0.9453
# Epoch 15/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1657 - accuracy: 0.9512
# Epoch 16/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1602 - accuracy: 0.9512
# Epoch 17/150
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1489 - accuracy: 0.9531
# Epoch 18/150
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1373 - accuracy: 0.9512
# Epoch 19/150
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1380 - accuracy: 0.9492
# Epoch 20/150
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1233 - accuracy: 0.9570
# Epoch 21/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1231 - accuracy: 0.9551
# Epoch 22/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1199 - accuracy: 0.9570
# Epoch 23/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1128 - accuracy: 0.9609
# Epoch 24/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1037 - accuracy: 0.9668
# Epoch 25/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1024 - accuracy: 0.9629
# Epoch 26/150
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1014 - accuracy: 0.9668
# Epoch 27/150
# 6/6 [==============================] - 0s 1ms/step - loss: 0.0974 - accuracy: 0.9727
# Epoch 28/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0898 - accuracy: 0.9707
# Epoch 29/150
# 6/6 [==============================] - 0s 1ms/step - loss: 0.0824 - accuracy: 0.9746
# Epoch 30/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0840 - accuracy: 0.9805
# Epoch 31/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0772 - accuracy: 0.9844
# Epoch 32/150
# 6/6 [==============================] - 0s 1ms/step - loss: 0.0809 - accuracy: 0.9805
# Epoch 33/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0692 - accuracy: 0.9805
# Epoch 34/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0791 - accuracy: 0.9824
# Epoch 35/150
# 6/6 [==============================] - 0s 1ms/step - loss: 0.0781 - accuracy: 0.9785
# Epoch 36/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0741 - accuracy: 0.9863
# Epoch 37/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0662 - accuracy: 0.9844
# Epoch 38/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0668 - accuracy: 0.9863
# Epoch 39/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0751 - accuracy: 0.9844
# Epoch 40/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0720 - accuracy: 0.9805
# Epoch 41/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0682 - accuracy: 0.9844
# Epoch 42/150
# 6/6 [==============================] - 0s 1ms/step - loss: 0.0665 - accuracy: 0.9824
# Epoch 43/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0657 - accuracy: 0.9863
# Epoch 44/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0581 - accuracy: 0.9863
# Epoch 45/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0643 - accuracy: 0.9863
# Epoch 46/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0599 - accuracy: 0.9863
# Epoch 47/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0551 - accuracy: 0.9844
# Epoch 48/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0584 - accuracy: 0.9863
# Epoch 49/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0547 - accuracy: 0.9844
# Epoch 50/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0589 - accuracy: 0.9824
# Epoch 51/150
# 6/6 [==============================] - 0s 1ms/step - loss: 0.0562 - accuracy: 0.9844
# Epoch 52/150
# 6/6 [==============================] - 0s 1ms/step - loss: 0.0574 - accuracy: 0.9824
# Epoch 53/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0562 - accuracy: 0.9863
# Epoch 54/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0475 - accuracy: 0.9883
# Epoch 55/150
# 6/6 [==============================] - 0s 1ms/step - loss: 0.0506 - accuracy: 0.9844
# Epoch 56/150
# 6/6 [==============================] - 0s 1ms/step - loss: 0.0497 - accuracy: 0.9844
# Epoch 57/150
# 6/6 [==============================] - 0s 1ms/step - loss: 0.0518 - accuracy: 0.9863
# Epoch 58/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0466 - accuracy: 0.9863
# Epoch 59/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0534 - accuracy: 0.9863
# Epoch 60/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0486 - accuracy: 0.9863
# Epoch 61/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0456 - accuracy: 0.9863
# Epoch 62/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0510 - accuracy: 0.9863
# Epoch 63/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0488 - accuracy: 0.9863
# Epoch 64/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0497 - accuracy: 0.9844
# Epoch 65/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0476 - accuracy: 0.9883
# Epoch 66/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0466 - accuracy: 0.9883
# Epoch 67/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0500 - accuracy: 0.9883
# Epoch 68/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0493 - accuracy: 0.9863
# Epoch 69/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0414 - accuracy: 0.9863
# Epoch 70/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0510 - accuracy: 0.9902
# Epoch 71/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0461 - accuracy: 0.9902
# Epoch 72/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0454 - accuracy: 0.9863
# Epoch 73/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0483 - accuracy: 0.9883
# Epoch 74/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0429 - accuracy: 0.9863
# Epoch 75/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0465 - accuracy: 0.9902
# Epoch 76/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0418 - accuracy: 0.9902
# Epoch 77/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0411 - accuracy: 0.9883
# Epoch 78/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0386 - accuracy: 0.9883
# Epoch 79/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0454 - accuracy: 0.9883
# Epoch 80/150
# 6/6 [==============================] - 0s 1ms/step - loss: 0.0464 - accuracy: 0.9883
# Epoch 81/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0431 - accuracy: 0.9902
# Epoch 82/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0450 - accuracy: 0.9863
# Epoch 83/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0401 - accuracy: 0.9902
# Epoch 84/150
# 6/6 [==============================] - 0s 1ms/step - loss: 0.0378 - accuracy: 0.9883
# Epoch 85/150
# 6/6 [==============================] - 0s 1ms/step - loss: 0.0403 - accuracy: 0.9844
# Epoch 86/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0424 - accuracy: 0.9883
# Epoch 87/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0388 - accuracy: 0.9883
# Epoch 88/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0443 - accuracy: 0.9824
# Epoch 89/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0394 - accuracy: 0.9883
# Epoch 90/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0384 - accuracy: 0.9902
# Epoch 91/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0367 - accuracy: 0.9902
# Epoch 92/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0355 - accuracy: 0.9883
# Epoch 93/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0323 - accuracy: 0.9883
# Epoch 94/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0364 - accuracy: 0.9902
# Epoch 95/150
# 6/6 [==============================] - 0s 1ms/step - loss: 0.0332 - accuracy: 0.9922
# Epoch 96/150
# 6/6 [==============================] - 0s 1ms/step - loss: 0.0382 - accuracy: 0.9902
# Epoch 97/150
# 6/6 [==============================] - 0s 1ms/step - loss: 0.0398 - accuracy: 0.9863
# Epoch 98/150
# 6/6 [==============================] - 0s 1ms/step - loss: 0.0383 - accuracy: 0.9863
# Epoch 99/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0352 - accuracy: 0.9883
# Epoch 100/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0372 - accuracy: 0.9902
# Epoch 101/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0330 - accuracy: 0.9902
# Epoch 102/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0327 - accuracy: 0.9902
# Epoch 103/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0406 - accuracy: 0.9863
# Epoch 104/150
# 6/6 [==============================] - 0s 1ms/step - loss: 0.0335 - accuracy: 0.9883
# Epoch 105/150
# 6/6 [==============================] - 0s 1ms/step - loss: 0.0349 - accuracy: 0.9902
# Epoch 106/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0309 - accuracy: 0.9922
# Epoch 107/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0316 - accuracy: 0.9863
# Epoch 108/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0261 - accuracy: 0.9922
# Epoch 109/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0449 - accuracy: 0.9883
# Epoch 110/150
# 6/6 [==============================] - 0s 1ms/step - loss: 0.0321 - accuracy: 0.9902
# Epoch 111/150
# 6/6 [==============================] - 0s 1ms/step - loss: 0.0313 - accuracy: 0.9922
# Epoch 112/150
# 6/6 [==============================] - 0s 1ms/step - loss: 0.0330 - accuracy: 0.9902
# Epoch 113/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0315 - accuracy: 0.9902
# Epoch 114/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0288 - accuracy: 0.9941
# Epoch 115/150
# 6/6 [==============================] - 0s 1ms/step - loss: 0.0249 - accuracy: 0.9922
# Epoch 116/150
# 6/6 [==============================] - 0s 1ms/step - loss: 0.0230 - accuracy: 0.9941
# Epoch 117/150
# 6/6 [==============================] - 0s 1ms/step - loss: 0.0313 - accuracy: 0.9922
# Epoch 118/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0259 - accuracy: 0.9902
# Epoch 119/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0256 - accuracy: 0.9922
# Epoch 120/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0237 - accuracy: 0.9941
# Epoch 121/150
# 6/6 [==============================] - 0s 1ms/step - loss: 0.0250 - accuracy: 0.9922
# Epoch 122/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0248 - accuracy: 0.9902
# Epoch 123/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0256 - accuracy: 0.9941
# Epoch 124/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0297 - accuracy: 0.9902
# Epoch 125/150
# 6/6 [==============================] - 0s 1ms/step - loss: 0.0227 - accuracy: 0.9941
# Epoch 126/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0244 - accuracy: 0.9941
# Epoch 127/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0219 - accuracy: 0.9941
# Epoch 128/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0264 - accuracy: 0.9922
# Epoch 129/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0232 - accuracy: 0.9941
# Epoch 130/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0229 - accuracy: 0.9941
# Epoch 131/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0165 - accuracy: 0.9941
# Epoch 132/150
# 6/6 [==============================] - 0s 1ms/step - loss: 0.0195 - accuracy: 0.9941
# Epoch 133/150
# 6/6 [==============================] - 0s 1ms/step - loss: 0.0164 - accuracy: 0.9941
# Epoch 134/150
# 6/6 [==============================] - ETA: 0s - loss: 0.0212 - accuracy: 1.00 - 0s 1ms/step - loss: 0.0214 - accuracy: 0.9961
# Epoch 135/150
# 6/6 [==============================] - 0s 1ms/step - loss: 0.0188 - accuracy: 0.9941
# Epoch 136/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0178 - accuracy: 0.9941
# Epoch 137/150
# 6/6 [==============================] - 0s 1ms/step - loss: 0.0211 - accuracy: 0.9941
# Epoch 138/150
# 6/6 [==============================] - 0s 1ms/step - loss: 0.0198 - accuracy: 0.9941
# Epoch 139/150
# 6/6 [==============================] - 0s 1ms/step - loss: 0.0179 - accuracy: 0.9922
# Epoch 140/150
# 6/6 [==============================] - 0s 1ms/step - loss: 0.0212 - accuracy: 0.9961
# Epoch 141/150
# 6/6 [==============================] - 0s 1ms/step - loss: 0.0198 - accuracy: 0.9922
# Epoch 142/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0193 - accuracy: 0.9941
# Epoch 143/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0181 - accuracy: 0.9961
# Epoch 144/150
# 6/6 [==============================] - 0s 1ms/step - loss: 0.0189 - accuracy: 0.9961
# Epoch 145/150
# 6/6 [==============================] - 0s 1ms/step - loss: 0.0173 - accuracy: 0.9961
# Epoch 146/150
# 6/6 [==============================] - 0s 1ms/step - loss: 0.0146 - accuracy: 0.9961
# Epoch 147/150
# 6/6 [==============================] - 0s 1ms/step - loss: 0.0163 - accuracy: 0.9941
# Epoch 148/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0150 - accuracy: 0.9941
# Epoch 149/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0173 - accuracy: 0.9941
# Epoch 150/150
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0157 - accuracy: 0.9961

# %%
# Predicting the Test set results
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# %%
print("Our accuracy is {}%".format(((cm[0][0] + cm[1][1])/57)*100))
# Out:
# Our accuracy is 98.24561403508771%

# %%
sns.heatmap(cm,annot=True)
#plt.savefig('h.png')
